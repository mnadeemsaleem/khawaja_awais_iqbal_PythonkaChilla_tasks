# %% [markdown]
# # Pandas Case studies
# We will check the data Urban and rural population over the years in pakistan

# %%
# Import Libraries

import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
pop=pd.read_csv('FAOSTAT_data_1-13-2022.csv')
# Saving dataframe into csv file
pop.to_csv
# pop.to_excel
pop.head(4)
# Out:
#   Domain Code             Domain  Area Code      Area  Element Code  \
# 0          OA  Annual population        165  Pakistan           551
# 1          OA  Annual population        165  Pakistan           561
# 2          OA  Annual population        165  Pakistan           561
# 3          OA  Annual population        165  Pakistan           551
#
#             Element  Item Code                       Item  Year Code  Year  \
# 0  Rural population       3010  Population - Est. & Proj.       1990  1990
# 1  Urban population       3010  Population - Est. & Proj.       1990  1990
# 2  Urban population       3010  Population - Est. & Proj.       1991  1991
# 3  Rural population       3010  Population - Est. & Proj.       1991  1991
#
#            Unit      Value Flag                Flag Description  \
# 0  1000 persons  74754.921    X  International reliable sources
# 1  1000 persons  32923.693    X  International reliable sources
# ...

# %%
# Basic Statistics
pop.describe()
# Out:
#        Area Code  Element Code  Item Code    Year Code         Year  \
# count       58.0     58.000000       58.0    58.000000    58.000000
# mean       165.0    556.000000     3010.0  2004.000000  2004.000000
# std          0.0      5.043669        0.0     8.439672     8.439672
# min        165.0    551.000000     3010.0  1990.000000  1990.000000
# 25%        165.0    551.000000     3010.0  1997.000000  1997.000000
# 50%        165.0    556.000000     3010.0  2004.000000  2004.000000
# 75%        165.0    561.000000     3010.0  2011.000000  2011.000000
# max        165.0    561.000000     3010.0  2018.000000  2018.000000
#
#                Value
# count      58.000000
# mean    76031.216966
# std     28181.561500
# min     32923.693000
# 25%     51276.889250
# 50%     74192.675500
# 75%     99409.902500
# max    127183.388000

# %%
pop.head(4)
# Out:
#   Domain Code             Domain  Area Code      Area  Element Code  \
# 0          OA  Annual population        165  Pakistan           551
# 1          OA  Annual population        165  Pakistan           561
# 2          OA  Annual population        165  Pakistan           561
# 3          OA  Annual population        165  Pakistan           551
#
#             Element  Item Code                       Item  Year Code  Year  \
# 0  Rural population       3010  Population - Est. & Proj.       1990  1990
# 1  Urban population       3010  Population - Est. & Proj.       1990  1990
# 2  Urban population       3010  Population - Est. & Proj.       1991  1991
# 3  Rural population       3010  Population - Est. & Proj.       1991  1991
#
#            Unit      Value Flag                Flag Description  \
# 0  1000 persons  74754.921    X  International reliable sources
# 1  1000 persons  32923.693    X  International reliable sources
# ...

# %%
# droping colums and make new data

new_pop=pop.drop(['Area Code','Item Code','Year Code'], axis=1)
new_pop.head()
# Out:
#   Domain Code             Domain      Area  Element Code           Element  \
# 0          OA  Annual population  Pakistan           551  Rural population
# 1          OA  Annual population  Pakistan           561  Urban population
# 2          OA  Annual population  Pakistan           561  Urban population
# 3          OA  Annual population  Pakistan           551  Rural population
# 4          OA  Annual population  Pakistan           551  Rural population
#
#                         Item  Year          Unit      Value Flag  \
# 0  Population - Est. & Proj.  1990  1000 persons  74754.921    X
# 1  Population - Est. & Proj.  1990  1000 persons  32923.693    X
# 2  Population - Est. & Proj.  1991  1000 persons  34133.440    X
# 3  Population - Est. & Proj.  1991  1000 persons  76596.980    X
# 4  Population - Est. & Proj.  1992  1000 persons  78397.927    X
#
#                  Flag Description  \
# 0  International reliable sources
# 1  International reliable sources
# ...

# %%
# Work another way

pop.drop(['Area Code','Item Code','Year Code'], axis=1).head()
# Out:
#   Domain Code             Domain      Area  Element Code           Element  \
# 0          OA  Annual population  Pakistan           551  Rural population
# 1          OA  Annual population  Pakistan           561  Urban population
# 2          OA  Annual population  Pakistan           561  Urban population
# 3          OA  Annual population  Pakistan           551  Rural population
# 4          OA  Annual population  Pakistan           551  Rural population
#
#                         Item  Year          Unit      Value Flag  \
# 0  Population - Est. & Proj.  1990  1000 persons  74754.921    X
# 1  Population - Est. & Proj.  1990  1000 persons  32923.693    X
# 2  Population - Est. & Proj.  1991  1000 persons  34133.440    X
# 3  Population - Est. & Proj.  1991  1000 persons  76596.980    X
# 4  Population - Est. & Proj.  1992  1000 persons  78397.927    X
#
#                  Flag Description  \
# 0  International reliable sources
# 1  International reliable sources
# ...

# %%
pop.mean()
# Out:
# C:\Users\khawaja\AppData\Local\Temp/ipykernel_1864/431921984.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   pop.mean()
# Area Code         165.000000
# Element Code      556.000000
# Item Code        3010.000000
# Year Code        2004.000000
# Year             2004.000000
# Value           76031.216966
# dtype: float64

# %%
pop.groupby(['Element','Year']).mean()
# Out:
#                        Area Code  Element Code  Item Code  Year Code  \
# Element          Year
# Rural population 1990      165.0         551.0     3010.0     1990.0
#                  1991      165.0         551.0     3010.0     1991.0
#                  1992      165.0         551.0     3010.0     1992.0
#                  1993      165.0         551.0     3010.0     1993.0
#                  1994      165.0         551.0     3010.0     1994.0
#                  1995      165.0         551.0     3010.0     1995.0
#                  1996      165.0         551.0     3010.0     1996.0
#                  1997      165.0         551.0     3010.0     1997.0
#                  1998      165.0         551.0     3010.0     1998.0
#                  1999      165.0         551.0     3010.0     1999.0
#                  2000      165.0         551.0     3010.0     2000.0
#                  2001      165.0         551.0     3010.0     2001.0
# ...

# %%
pop[pop['Element Code'] > 551 ].mean()
# Out:
# C:\Users\khawaja\AppData\Local\Temp/ipykernel_1864/2864082418.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   pop[pop['Element Code'] > 551 ].mean()
# Area Code         165.000000
# Element Code      561.000000
# Item Code        3010.000000
# Year Code        2004.000000
# Year             2004.000000
# Value           51784.796724
# dtype: float64

# %%
pop[pop['Element Code'] > 551 ].groupby(['Element','Year']).mean()
# Out:
#                        Area Code  Element Code  Item Code  Year Code  \
# Element          Year
# Urban population 1990      165.0         561.0     3010.0     1990.0
#                  1991      165.0         561.0     3010.0     1991.0
#                  1992      165.0         561.0     3010.0     1992.0
#                  1993      165.0         561.0     3010.0     1993.0
#                  1994      165.0         561.0     3010.0     1994.0
#                  1995      165.0         561.0     3010.0     1995.0
#                  1996      165.0         561.0     3010.0     1996.0
#                  1997      165.0         561.0     3010.0     1997.0
#                  1998      165.0         561.0     3010.0     1998.0
#                  1999      165.0         561.0     3010.0     1999.0
#                  2000      165.0         561.0     3010.0     2000.0
#                  2001      165.0         561.0     3010.0     2001.0
# ...

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# p1=sns.load_dataset("pop")

#defining a color pelette
pel= sns.color_palette('rocket_r')

# creating plot
sns.set_theme(style="ticks")
pop=pd.read_csv('FAOSTAT_data_1-13-2022.csv')
# Saving dataframe into csv file
pop.to_csv
 

# Define the palette as a list to specify exact values
palette = sns.color_palette("rocket_r")

# Plot the lines on two facets
sns.relplot(
    data=pop,
    x="Element", y="Year",
    hue="Value", size="choice", col="align",
    kind="line", size_order=["T1", "T2"], palette=pel,
    height=5, aspect=.75, facet_kws=dict(sharex=False),
)

plt.title("Population")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10040/2554901713.py in <module>
#      20
#      21 # Plot the lines on two facets
# ---> 22 sns.relplot(
#      23     data="pop",
#      24     x="Element", y="Year",
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\relational.py in relplot(x, y, hue, size, style, data, row, col, col_wrap, row_order, col_order, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, dashes, style_order, legend, kind, height, aspect, facet_kws, units, **kwargs)
#     945
# ...
